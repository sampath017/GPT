# %% [markdown]
# ## Load the sequence

# %%
with open("../output/combined_text.txt", "r") as f:
    text_sequence = f.read()

len(text_sequence)
# Out:
# 85471

# %% [markdown]
# ## BPE algorithm

# %% [markdown]
# I am using the [minBPE](https://github.com/karpathy/minbpe) repository to tokenize the sequence of text.

# %%
import sys
sys.path.append('..')

# %% [markdown]
# Start by training the tokenizer on the text sequence that you saved in the previous notebook.

# %%
from minbpe import BasicTokenizer

tokenizer = BasicTokenizer()
vocab_size = 50257
tokenizer.train(text_sequence, vocab_size=vocab_size)
# Out:
#  41%|████      | 20611/50001 [01:34<02:15, 217.55it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 tokenizer = BasicTokenizer()
#       4 vocab_size = 50257
# ----> 5 tokenizer.train(text_sequence, vocab_size=vocab_size)
#
# File /workspaces/GPT/Train_Your_Language_Model_Course/notebooks/../minbpe/basic.py:36, in BasicTokenizer.train(self, text, vocab_size, verbose)
#      34 stats = get_stats(ids)
#      35 # find the pair with the highest count
# ---> 36 pair = max(stats, key=stats.get)
#      37 # mint a new token: assign it the next available id
#      38 idx = 256 + i
#
# ValueError: max() iterable argument is empty

# %% [markdown]
# Visualize the vocabulary.

# %%
vocab = tokenizer.vocab
vocab

# %% [markdown]
# Test the tokenizer.

# %%
tokenizer.encode("Salam labas")

# %%
tokenizer.decode([702, 310, 346, 115])
# Out:
# 'Salam labas'

# %% [markdown]
# Add special tokens to the vocabulary. These tokens are going to be used a lot in the fine-tuning step.

# %%
max_vocab_id = list(tokenizer.vocab.keys())[-1]
tokenizer.special_tokens = {
    "<|startoftext|>": max_vocab_id + 1,
    "<|separator|>": max_vocab_id + 2,
    "<|endoftext|>": max_vocab_id + 3,
    "<|unk|>": max_vocab_id + 4
}

# %% [markdown]
# I have more than 618K tokens for training and validation. This is pretty good, but if you can add more, that would be even better.

# %%
len(tokenizer.encode(text_sequence))

# %% [markdown]
# Save the tokenizer

# %%
tokenizer.save(file_prefix="../output/tokenizer/my_tokenizer")
